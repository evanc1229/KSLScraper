# %%
# Most straight-forward way to import a library in Python
import requests

# BeautifulSoup is a module inside the "bs4" library, we only import the BeautifulSoup module
from bs4 import BeautifulSoup

# Pandas and numpy are always helpful
import numpy as np
import pandas as pd
import tweepy

# %%
headers = {"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36"}
ksl_raw = requests.get('https://classifieds.ksl.com/search/keyword/arcteryx/priceFrom/0/priceTo/1000/Private/Sale',headers=headers).text
ksl_soup = BeautifulSoup(ksl_raw,'html.parser')
URL = 'https://classifieds.ksl.com/search/keyword/arcteryx/priceFrom/0/priceTo/1000/Private/Sale'

# %%
raw_listings = ksl_soup.find_all('section',{'class':'listing-item featured'})

# %%
def ExtractListingInfoDF(raw_listings):
    Titles = []
    Prices = []
    Locations = []
    for i in raw_listings:
        Titles.append(i.find('img')['alt'])
        Prices.append(i.find('div',{'class':'item-info-price info-line'}).text)
        Locations.append(i.find('a',{'class':'item-address'}).text)
    return pd.DataFrame({'Titles':Titles, 'Prices':Prices, 'Locations':Locations})

# %%
New_Listings = ExtractListingInfoDF(raw_listings)

# %%
New_Listings.head(23)
# Out:
#                                                Titles   Prices  \
# 0                           Womens Arcteryx XS Jacket   $20.00
# 1            Arcteryx Side Winder Size LARGE $500 OBO  $500.00
# 2              Arcteryx Long Sleeve Button Size Small   $25.00
# 3             Men’s Arc'teryx Sabre AR Pants Arcteryx  $280.00
# 4             Men’s Arc'teryx Sabre AR Pants Arcteryx  $280.00
# 5                 Arcteryx , Kuhl, North Face Clothes   $35.00
# 6     Arcteryx, Kuhl, North Face Clothes Will Deliver   $25.00
# 7                        New Arcteryx Patera Parka XL  $500.00
# 8                  Women's Arcteryx Backpack: Bora 75  $120.00
# 9                     Arcteryx Women's Gore-Tex Shell   $80.00
# 10                                  ArcTeryx Alpha AR  $300.00
# 11            Arcteryx Venta MX Hoody Jacket; Size XL  $360.00
# 12  Arcteryx Sabre Pant Gore Tex, Men's Large Like...  $360.00
# 13                              Arcteryx gortex shell  $300.00
# 14                      Women’s Arcteryx Pants Size 8  $185.00
# 15    Arcteryx Gryson Shirt LS Men's Flannel Sz Small   $60.00
# 16                          Arcteryx Softshell Jacket   $60.00
# 17                 Arcteryx Atom Lt Size Large Womens  $120.00
# 18                   Arcteryx Acrux FL Womens 7.5 NEW   $80.00
# 19                                 Arcteryx Ski Pants  $299.00
# 20                                           ARCTERYX   $60.00
# 21            Arcteryx Beta AR Pants Men's (M, Black)  $325.00
#
#              Locations
# 0             Lehi, UT
# 1        Millcreek, UT
# 2           Draper, UT
# 3   Salt Lake City, UT
# 4   Salt Lake City, UT
# 5           Layton, UT
# 6           Layton, UT
# 7   Salt Lake City, UT
# 8   Salt Lake City, UT
# 9   Salt Lake City, UT
# 10            Lehi, UT
# 11          Draper, UT
# 12          Draper, UT
# 13           Ogden, UT
# 14    Brigham City, UT
# 15       Park City, UT
# 16  Salt Lake City, UT
# 17       Millcreek, UT
# 18          Nibley, UT
# 19  Salt Lake City, UT
# 20           Ogden, UT
# 21          Nibley, UT

# %%
History = pd.read_csv('History.csv').iloc[:,1:]

# %%
History.head(23)
# Out:
#                                                Titles   Prices  \
# 0                           Womens Arcteryx XS Jacket   $20.00
# 1            Arcteryx Side Winder Size LARGE $500 OBO  $500.00
# 2              Arcteryx Long Sleeve Button Size Small   $25.00
# 3             Men’s Arc'teryx Sabre AR Pants Arcteryx  $280.00
# 4             Men’s Arc'teryx Sabre AR Pants Arcteryx  $280.00
# 5             Men’s Arc'teryx Sabre AR Pants Arcteryx  $280.00
# 6             Men’s Arc'teryx Sabre AR Pants Arcteryx  $280.00
# 7                 Arcteryx , Kuhl, North Face Clothes   $35.00
# 8     Arcteryx, Kuhl, North Face Clothes Will Deliver   $25.00
# 9                        New Arcteryx Patera Parka XL  $500.00
# 10                 Women's Arcteryx Backpack: Bora 75  $120.00
# 11                    Arcteryx Women's Gore-Tex Shell   $80.00
# 12                                  ArcTeryx Alpha AR  $300.00
# 13            Arcteryx Venta MX Hoody Jacket; Size XL  $360.00
# 14  Arcteryx Sabre Pant Gore Tex, Men's Large Like...  $360.00
# 15                              Arcteryx gortex shell  $300.00
# 16                      Women’s Arcteryx Pants Size 8  $185.00
# 17    Arcteryx Gryson Shirt LS Men's Flannel Sz Small   $60.00
# 18                          Arcteryx Softshell Jacket   $60.00
# 19                 Arcteryx Atom Lt Size Large Womens  $120.00
# 20                   Arcteryx Acrux FL Womens 7.5 NEW   $80.00
# 21                                 Arcteryx Ski Pants  $299.00
# 22                                           ARCTERYX   $60.00
#
#              Locations
# 0             Lehi, UT
# 1        Millcreek, UT
# 2           Draper, UT
# 3   Salt Lake City, UT
# 4   Salt Lake City, UT
# 5   Salt Lake City, UT
# 6   Salt Lake City, UT
# 7           Layton, UT
# 8           Layton, UT
# 9   Salt Lake City, UT
# 10  Salt Lake City, UT
# 11  Salt Lake City, UT
# 12            Lehi, UT
# 13          Draper, UT
# 14          Draper, UT
# 15           Ogden, UT
# 16    Brigham City, UT
# 17       Park City, UT
# 18  Salt Lake City, UT
# 19       Millcreek, UT
# 20          Nibley, UT
# 21  Salt Lake City, UT
# 22           Ogden, UT

# %%
merged = pd.merge(New_Listings, History, on=['Titles','Prices','Locations'], how='outer', indicator=True)

# %%
merged
# Out:
#                                                Titles   Prices  \
# 0                           Womens Arcteryx XS Jacket   $20.00
# 1            Arcteryx Side Winder Size LARGE $500 OBO  $500.00
# 2              Arcteryx Long Sleeve Button Size Small   $25.00
# 3             Men’s Arc'teryx Sabre AR Pants Arcteryx  $280.00
# 4             Men’s Arc'teryx Sabre AR Pants Arcteryx  $280.00
# 5             Men’s Arc'teryx Sabre AR Pants Arcteryx  $280.00
# 6             Men’s Arc'teryx Sabre AR Pants Arcteryx  $280.00
# 7             Men’s Arc'teryx Sabre AR Pants Arcteryx  $280.00
# 8             Men’s Arc'teryx Sabre AR Pants Arcteryx  $280.00
# 9             Men’s Arc'teryx Sabre AR Pants Arcteryx  $280.00
# 10            Men’s Arc'teryx Sabre AR Pants Arcteryx  $280.00
# 11                Arcteryx , Kuhl, North Face Clothes   $35.00
# 12    Arcteryx, Kuhl, North Face Clothes Will Deliver   $25.00
# 13                       New Arcteryx Patera Parka XL  $500.00
# 14                 Women's Arcteryx Backpack: Bora 75  $120.00
# 15                    Arcteryx Women's Gore-Tex Shell   $80.00
# 16                                  ArcTeryx Alpha AR  $300.00
# 17            Arcteryx Venta MX Hoody Jacket; Size XL  $360.00
# 18  Arcteryx Sabre Pant Gore Tex, Men's Large Like...  $360.00
# 19                              Arcteryx gortex shell  $300.00
# 20                      Women’s Arcteryx Pants Size 8  $185.00
# 21    Arcteryx Gryson Shirt LS Men's Flannel Sz Small   $60.00
# 22                          Arcteryx Softshell Jacket   $60.00
# 23                 Arcteryx Atom Lt Size Large Womens  $120.00
# 24                   Arcteryx Acrux FL Womens 7.5 NEW   $80.00
# 25                                 Arcteryx Ski Pants  $299.00
# 26                                           ARCTERYX   $60.00
# 27            Arcteryx Beta AR Pants Men's (M, Black)  $325.00
#
#              Locations _merge
# 0             Lehi, UT   both
# 1        Millcreek, UT   both
# 2           Draper, UT   both
# 3   Salt Lake City, UT   both
# 4   Salt Lake City, UT   both
# 5   Salt Lake City, UT   both
# 6   Salt Lake City, UT   both
# 7   Salt Lake City, UT   both
# 8   Salt Lake City, UT   both
# 9   Salt Lake City, UT   both
# 10  Salt Lake City, UT   both
# 11          Layton, UT   both
# 12          Layton, UT   both
# 13  Salt Lake City, UT   both
# 14  Salt Lake City, UT   both
# 15  Salt Lake City, UT   both
# 16            Lehi, UT   both
# 17          Draper, UT   both
# 18          Draper, UT   both
# 19           Ogden, UT   both
# 20    Brigham City, UT   both
# 21       Park City, UT   both
# 22  Salt Lake City, UT   both
# 23       Millcreek, UT   both
# 24          Nibley, UT   both
# 25  Salt Lake City, UT   both
# 26           Ogden, UT   both
# 27          Nibley, UT   both

# %%
tweet = merged[merged['_merge'] == 'left_only'].iloc[:,:-1]

# %%
tweet
# Out:
# Empty DataFrame
# Columns: [Titles, Prices, Locations]
# Index: []

# %%
merged.iloc[:,:-1].to_csv('History.csv')

# %%
consumer_key = '2LlCS74i3TcPCB1f1rMj2LrXi'
consumer_secret = 'fLQw16Rx2VSmnWmlGX6wQEO20ODnFVdQ4J8qPWTVG9npVzjRDv' 
access_token = '1490836142714810370-byS7DykGYT6MVWWJQv3SnPqHisTiD6' 
access_token_secret = 'X5llf5ERCIaTSD8MY8kWapbecwoMwJq2YGQp5IbnyCrtx'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
def GenerateTweetText(df_tweets):
    tweets = []
    for index,lab,price,loc in df_tweets.itertuples():
        tweets.append(f'GEAR ALERT: {lab} for {price} in {loc}')
    return tweets

# %%
to_tweet = list(set(GenerateTweetText(tweet)))

# %%
for i in to_tweet:
    try:
        api.update_status(i)
    except:
        pass
